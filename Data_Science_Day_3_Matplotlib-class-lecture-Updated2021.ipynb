# %% [markdown]
# # Data Science Visualization - Matplotlib

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Matplotlib</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Data Visulation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Different Types of Charts <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Basics <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Customization <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Axis Labels & Line Marks <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Legend & Line Labels <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Subplots <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Presentation Worthiness <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Box Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Scatter Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; k) Histograms <br>

# %% [markdown]
# ### Data Visualization <br>
# <p>Data visualization is one of the most powerful tools an analyst has for two main reasons. Firstly, it is unrivalled in it's ability to guide the analysts hand in determining 'what to look at next'. Often a visual is revealing of patterns in the data that are not easily discernable by just looking at dataframes. Secondly, they are an analysts greatest communication tool. Very often professional analysts need to present their results to groups of people responsible for taking action based on what the data says. Visuals can tell your story much better then raw numbers, so let's talk a little bit about how to make effective visuals that make a point.</p>

# %% [markdown]
# ##### Importing

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp38-cp38-win32.whl (7.0 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\todds\anaconda3\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in c:\users\todds\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\todds\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\todds\anaconda3\lib\site-packages (from matplotlib) (8.3.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-win32.whl (42 kB)
# Requirement already satisfied: six in c:\users\todds\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # standard
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:172: RuntimeWarning: divide by zero encountered in exp2
#   eps=exp2(ld(-112)),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:51: RuntimeWarning: divide by zero encountered in log10
#   self.precision = int(-log10(self.eps))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:52: RuntimeWarning: divide by zero encountered in power
#   self.resolution = float_to_float(float_conv(10) ** (-self.precision))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:184: RuntimeWarning: divide by zero encountered in exp2
#   epsneg_f80 = exp2(ld(-64))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:185: RuntimeWarning: divide by zero encountered in exp2
#   tiny_f80 = exp2(ld(-16382))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:199: RuntimeWarning: divide by zero encountered in exp2
#   eps=exp2(ld(-63)),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:211: RuntimeWarning: divide by zero encountered in nextafter
#   huge_dd = (umath.nextafter(ld(inf), ld(0))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:224: RuntimeWarning: divide by zero encountered in exp2
#   eps=exp2(ld(-105)),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:225: RuntimeWarning: divide by zero encountered in exp2
#   epsneg= exp2(ld(-106)),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:227: RuntimeWarning: divide by zero encountered in exp2
#   tiny=exp2(ld(-1022)))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\__init__.py:343: RuntimeWarning: divide by zero encountered in subtract
#   if not abs(x.dot(x) - 2.0) < 1e-5:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\__init__.py:343: RuntimeWarning: divide by zero encountered in absolute
#   if not abs(x.dot(x) - 2.0) < 1e-5:
# <frozen importlib._bootstrap>:219: RuntimeWarning: divide by zero encountered in add
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:127: RuntimeWarning: divide by zero encountered in multiply
#   start = asanyarray(start) * 1.0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:128: RuntimeWarning: divide by zero encountered in multiply
#   stop  = asanyarray(stop)  * 1.0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:134: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = stop - start
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:141: RuntimeWarning: divide by zero encountered in double_scalars
#   step = delta / div
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:151: RuntimeWarning: divide by zero encountered in multiply
#   y *= step
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:161: RuntimeWarning: divide by zero encountered in add
#   y += start
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\colors.py:989: RuntimeWarning: divide by zero encountered in double_scalars
#   [(1.0 - x, y1, y0) for x, y0, y1 in reversed(data)])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\markers.py:796: RuntimeWarning: divide by zero encountered in true_divide
#   np.array([(-1, -3), (+1, -3), (+1, -1), (+3, -1), (+3, +1), (+1, +1),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\markers.py:800: RuntimeWarning: divide by zero encountered in true_divide
#   np.array([(+3, 0), (+3, +1), (+1, +1), (+1, +3),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\markers.py:820: RuntimeWarning: divide by zero encountered in true_divide
#   np.array([(-1, -2), (0, -1), (+1, -2), (+2, -1), (+1, 0), (+2, +1),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\markers.py:825: RuntimeWarning: divide by zero encountered in true_divide
#   np.array([(+1, 0), (+2, +1), (+1, +2), (0, +1),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tri\triinterpolate.py:668: RuntimeWarning: divide by zero encountered in true_divide
#   gauss_w = np.ones([9], dtype=np.float64) / 9.

# %% [markdown]
# ### Different Types of Charts <br>
# <ul>
#     <li><b>Line Chart:</b> Exploring data over time</li>
#     <li><b>Bar Chart:</b> Comparing categories of data and tracks changes over time</li>
#     <li><b>Pie Chart:</b> Explore parts of a whole, i.e. fractions</li>
#     <li><b>Scatter Plot:</b> Similar to line charts, track correlations between two categories</li>
#     <li><b>Histogram:</b> Unrelated from bar charts, show distribution of variables</li>
#     <li><b>Candlestick Chart:</b> Used a lot in financial sector, i.e. can compare a stock over a period of time</li>
#     <li><b>Box Chart:</b> Looks identical to candlestick charts, compares minimum, 1st, medium, 3rd quartiles, and max values</li>
# </ul>
#
# <p>Depending on what you need to accomplish in conceptualizing your data, you will go with a specific type of chart to portray your data.</p>

# %% [markdown]
# ### Basics <br>
# <p>Plots can be as detailed as you'd like them to be, but the simplest plot to start with can be done in just a few lines:</p>

# %%
plt.plot([3, 12, 4, 16, 28, 3, 7, 14, 19])
plt.show()
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\figure.py:2241: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\figure.py:2241: RuntimeWarning: divide by zero encountered in less
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2031: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 0] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2032: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 1] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2033: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2034: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 0] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2035: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 1] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2036: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:378: RuntimeWarning: divide by zero encountered in double_scalars
#   return points[1, 0] - points[0, 0]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:384: RuntimeWarning: divide by zero encountered in double_scalars
#   return points[1, 1] - points[0, 1]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\function_base.py:1281: RuntimeWarning: divide by zero encountered in subtract
#   a = op(a[slice1], a[slice2])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2142: RuntimeWarning: divide by zero encountered in less_equal
#   if np.any(np.diff(steps) <= 0) or steps[-1] > 10 or steps[0] < 1:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2155: RuntimeWarning: divide by zero encountered in multiply
#   return np.concatenate([0.1 * steps[:-1], steps, [10 * steps[1]]])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2155: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.concatenate([0.1 * steps[:-1], steps, [10 * steps[1]]])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3438: RuntimeWarning: divide by zero encountered in isfinite
#   and not np.isfinite(converted_limit)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2827: RuntimeWarning: divide by zero encountered in isfinite
#   if (not np.isfinite(vmin)) or (not np.isfinite(vmax)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2840: RuntimeWarning: divide by zero encountered in double_scalars
#   if maxabsvalue < (1e6 / tiny) * np.finfo(float).tiny:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2012: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] += tx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2013: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] += ty
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:202: RuntimeWarning: divide by zero encountered in subtract
#   fig_tops, fig_bottoms = (top - cell_hs).reshape((-1, 2)).T
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:203: RuntimeWarning: divide by zero encountered in add
#   fig_lefts, fig_rights = (left + cell_ws).reshape((-1, 2)).T
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: divide by zero encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1041: RuntimeWarning: divide by zero encountered in not_equal
#   if np.any(self._points != other.get_points()):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1760: RuntimeWarning: divide by zero encountered in equal
#   return np.all(self.get_matrix() == other.get_matrix())
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2708: RuntimeWarning: divide by zero encountered in isfinite
#   x_values = np.extract(np.isfinite(x_values), x_values)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2725: RuntimeWarning: divide by zero encountered in int_scalars
#   i0 = stickies.searchsorted(x0 + tol) - 1
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2737: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (x1t - x0t) * margin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2738: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(delta):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2740: RuntimeWarning: divide by zero encountered in double_scalars
#   x0, x1 = inverse_trans.transform([x0t - delta, x1t + delta])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:396: RuntimeWarning: divide by zero encountered in double_scalars
#   return (x0, y0, x1 - x0, y1 - y0)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2265: RuntimeWarning: divide by zero encountered in double_scalars
#   length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2270: RuntimeWarning: divide by zero encountered in double_scalars
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2270: RuntimeWarning: divide by zero encountered in floor
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:96: RuntimeWarning: divide by zero encountered in isnan
#   return um.isnan(a)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:112: RuntimeWarning: divide by zero encountered in clip
#   return ufunc(*args, out=out, **kwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2027: RuntimeWarning: divide by zero encountered in true_divide
#   scale = 10 ** (math.log10(dv / n) // 1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2221: RuntimeWarning: divide by zero encountered in true_divide
#   raw_step = (_vmax - _vmin) / nbins
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2222: RuntimeWarning: divide by zero encountered in multiply
#   steps = self._extended_steps * scale
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2228: RuntimeWarning: divide by zero encountered in greater_equal
#   istep = np.nonzero(steps >= raw_step)[0][0]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2240: RuntimeWarning: divide by zero encountered in int_scalars
#   for istep in reversed(range(istep + 1)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2246: RuntimeWarning: divide by zero encountered in double_scalars
#   best_vmin = (_vmin // step) * step
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2253: RuntimeWarning: divide by zero encountered in double_scalars
#   low = edge.le(_vmin - best_vmin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2061: RuntimeWarning: divide by zero encountered in double_scalars
#   d, m = divmod(x, self.step)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2062: RuntimeWarning: divide by zero encountered in double_scalars
#   if self.closeto(m / self.step, 1):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2057: RuntimeWarning: divide by zero encountered in double_scalars
#   return abs(ms - edge) < tol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2254: RuntimeWarning: divide by zero encountered in double_scalars
#   high = edge.ge(_vmax - best_vmin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2068: RuntimeWarning: divide by zero encountered in double_scalars
#   d, m = divmod(x, self.step)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2069: RuntimeWarning: divide by zero encountered in double_scalars
#   if self.closeto(m / self.step, 0):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2071: RuntimeWarning: divide by zero encountered in double_scalars
#   return d + 1
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2255: RuntimeWarning: divide by zero encountered in double_scalars
#   ticks = np.arange(low, high + 1) * step + best_vmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2255: RuntimeWarning: divide by zero encountered in multiply
#   ticks = np.arange(low, high + 1) * step + best_vmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2255: RuntimeWarning: divide by zero encountered in add
#   ticks = np.arange(low, high + 1) * step + best_vmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2257: RuntimeWarning: divide by zero encountered in less_equal
#   nticks = ((ticks <= _vmax) & (ticks >= _vmin)).sum()
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2257: RuntimeWarning: divide by zero encountered in greater_equal
#   nticks = ((ticks <= _vmax) & (ticks >= _vmin)).sum()
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2257: RuntimeWarning: divide by zero encountered in bitwise_and
#   nticks = ((ticks <= _vmax) & (ticks >= _vmin)).sum()
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2260: RuntimeWarning: divide by zero encountered in add
#   return ticks + offset
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2530: RuntimeWarning: divide by zero encountered in double_scalars
#   length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2534: RuntimeWarning: divide by zero encountered in double_scalars
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2534: RuntimeWarning: divide by zero encountered in floor
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py:195: RuntimeWarning: divide by zero encountered in greater
#   return rgbaArr[:,:3].dot((.299, .587, .114)) > .5
# C:\Users\todds\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py:184: RuntimeWarning: divide by zero encountered in equal
#   if ticksLight.size and (ticksLight == ticksLight[0]).all():
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:390: RuntimeWarning: divide by zero encountered in subtract
#   return points[1] - points[0]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:827: RuntimeWarning: divide by zero encountered in double_scalars
#   return Bbox.from_extents(x0, y0, x0 + width, y0 + height)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:813: RuntimeWarning: divide by zero encountered in less_equal
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:813: RuntimeWarning: divide by zero encountered in bitwise_and
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:861: RuntimeWarning: divide by zero encountered in less_equal
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:861: RuntimeWarning: divide by zero encountered in bitwise_and
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:862: RuntimeWarning: divide by zero encountered in absolute
#   locs = np.abs(locs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:891: RuntimeWarning: divide by zero encountered in subtract
#   locs = (np.asarray(_locs) - self.offset) / 10. ** self.orderOfMagnitude
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:891: RuntimeWarning: divide by zero encountered in true_divide
#   locs = (np.asarray(_locs) - self.offset) / 10. ** self.orderOfMagnitude
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:275: RuntimeWarning: divide by zero encountered in reduce
#   umr_maximum(a, axis, None, out, keepdims),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:276: RuntimeWarning: divide by zero encountered in reduce
#   umr_minimum(a, axis, None, None, keepdims),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:274: RuntimeWarning: divide by zero encountered in subtract
#   return um.subtract(
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:58: RuntimeWarning: divide by zero encountered in multiply
#   return bound(*args, **kwds)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:58: RuntimeWarning: divide by zero encountered in rint
#   return bound(*args, **kwds)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   return bound(*args, **kwds)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:908: RuntimeWarning: divide by zero encountered in subtract
#   if np.abs(locs - np.round(locs, decimals=sigfigs)).max() < thresh:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:908: RuntimeWarning: divide by zero encountered in absolute
#   if np.abs(locs - np.round(locs, decimals=sigfigs)).max() < thresh:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:670: RuntimeWarning: divide by zero encountered in double_scalars
#   xp = (x - self.offset) / (10. ** self.orderOfMagnitude)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:1268: RuntimeWarning: divide by zero encountered in double_scalars
#   tol = (hi - lo) * 1e-5
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2904: RuntimeWarning: divide by zero encountered in double_scalars
#   rtol = (b - a) * rtol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2905: RuntimeWarning: divide by zero encountered in double_scalars
#   return a - rtol <= val <= b + rtol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2905: RuntimeWarning: divide by zero encountered in less_equal
#   return a - rtol <= val <= b + rtol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:379: RuntimeWarning: divide by zero encountered in double_scalars
#   width = xmax - xmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:380: RuntimeWarning: divide by zero encountered in double_scalars
#   height = ymax - ymin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:392: RuntimeWarning: divide by zero encountered in double_scalars
#   offsetx = (xmin + xmax) / 2
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:432: RuntimeWarning: divide by zero encountered in double_scalars
#   xmin -= offsetx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:433: RuntimeWarning: divide by zero encountered in double_scalars
#   ymin -= offsety
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:438: RuntimeWarning: divide by zero encountered in subtract
#   xys = M.transform(offset_layout) - (offsetx, offsety)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2622: RuntimeWarning: divide by zero encountered in double_scalars
#   x_scale = 1.0 / inw
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2623: RuntimeWarning: divide by zero encountered in double_scalars
#   y_scale = 1.0 / inh
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2624: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx = np.array([[x_scale, 0.0    , (-inl*x_scale)],
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2625: RuntimeWarning: divide by zero encountered in double_scalars
#   [0.0    , y_scale, (-inb*y_scale)],
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:652: RuntimeWarning: divide by zero encountered in add
#   return Bbox(self._points + (tx, ty))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:687: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(posx) or not np.isfinite(posy):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:709: RuntimeWarning: divide by zero encountered in double_scalars
#   x = x + posx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:710: RuntimeWarning: divide by zero encountered in double_scalars
#   y = y + posy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:712: RuntimeWarning: divide by zero encountered in double_scalars
#   y = canvash - y
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2095: RuntimeWarning: divide by zero encountered in double_scalars
#   (x, bottom - self.labelpad * self.figure.dpi / 72)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2127: RuntimeWarning: divide by zero encountered in double_scalars
#   y = bottom - self.OFFSETTEXTPAD * self.figure.dpi / 72
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:831: RuntimeWarning: divide by zero encountered in ceil
#   oom_max = np.ceil(math.log10(abs_max))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:832: RuntimeWarning: divide by zero encountered in double_scalars
#   oom = 1 + next(oom for oom in itertools.count(oom_max, -1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:833: RuntimeWarning: divide by zero encountered in double_scalars
#   if abs_min // 10 ** oom != abs_max // 10 ** oom)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:834: RuntimeWarning: divide by zero encountered in double_scalars
#   if (abs_max - abs_min) / 10 ** oom <= 1e-2:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:844: RuntimeWarning: divide by zero encountered in double_scalars
#   if abs_max // 10 ** oom >= 10**n
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:405: RuntimeWarning: divide by zero encountered in double_scalars
#   offsety = ymin + height - baseline / 2.0
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2366: RuntimeWarning: divide by zero encountered in double_scalars
#   (left - self.labelpad * self.figure.dpi / 72, y)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2392: RuntimeWarning: divide by zero encountered in double_scalars
#   (x, top + self.OFFSETTEXTPAD * self.figure.dpi / 72)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:692: RuntimeWarning: divide by zero encountered in maximum
#   x0 = np.maximum(bbox1.xmin, bbox2.xmin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:693: RuntimeWarning: divide by zero encountered in minimum
#   x1 = np.minimum(bbox1.xmax, bbox2.xmax)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:694: RuntimeWarning: divide by zero encountered in maximum
#   y0 = np.maximum(bbox1.ymin, bbox2.ymin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:695: RuntimeWarning: divide by zero encountered in minimum
#   y1 = np.minimum(bbox1.ymax, bbox2.ymax)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:4480: RuntimeWarning: divide by zero encountered in equal
#   if np.all(clip_extent.extents == axbbox.extents):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:180: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.x0 = bb0.x0 - padout
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.x1 = bb0.x1 + padin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:183: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.y0 = bb0.y0 - padout
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:184: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.y1 = bb0.y1 + padin
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:327: RuntimeWarning: divide by zero encountered in not_equal
#   mask[1:] = aux[1:] != aux[:-1]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:432: RuntimeWarning: divide by zero encountered in equal
#   mask = aux[1:] == aux[:-1]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: RuntimeWarning: divide by zero encountered in equal
#   mask |= (ar1 == a)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask |= (ar1 == a)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\figure.py:1651: RuntimeWarning: divide by zero encountered in isfinite
#   if (np.isfinite(b.width) and np.isfinite(b.height)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:648: RuntimeWarning: divide by zero encountered in add
#   return Bbox(points + [[-p, -p], [p, p]])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_bbox.py:65: RuntimeWarning: divide by zero encountered in double_scalars
#   w1, h1 = fig.bbox.width * dpi_scale, fig.bbox.height * dpi_scale
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_bbox.py:71: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.patch.set_bounds(x0 / w1, y0 / h1,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_bbox.py:72: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.bbox.width / w1, fig.bbox.height / h1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:768: RuntimeWarning: divide by zero encountered in double_scalars
#   x1 = self.convert_xunits(self._x0 + self._width)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:769: RuntimeWarning: divide by zero encountered in double_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:213: RuntimeWarning: divide by zero encountered in double_scalars
#   x = round(x + xo + xd)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:213: RuntimeWarning: divide by zero encountered in rint
#   x = round(x + xo + xd)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: divide by zero encountered in double_scalars
#   y = round(y + yo + yd)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: divide by zero encountered in rint
#   y = round(y + yo + yd)

# %% [markdown]
# ### Customization <br>
# <p>There's many customizable options when using Matplotlib, such as; line types, colors, labels, figure size, etc. We'll go over a few of them here:</p>

# %% [markdown]
# ##### Axis Labels & Line Marks

# %%
plt.plot([1,2,3,4,5], [23,45,67,78,89], 'yo-')
plt.plot([3,4,5,6,7,8], [22,33,90,105,110,120], 'rx:')
plt.xlabel('Increase Value')
plt.ylabel('Increase Time')
plt.show()

# %% [markdown]
# ##### Legend & Line Labels

# %%
plt.plot([1600, 1700, 1800, 1900, 2000], [1, 1.4, 1.6, 1.8, 2], 'ro-', label='First Demographic')
plt.plot([1600, 1700, 1800, 1900, 2000], [2, 2, 3, 3.1, 2.4], 'gx-', label='Second Demographic')
plt.ylabel('Population (Billions)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# ### Subplots <br>
# <p>Using the subplots method, you're able to create multiple plots within a single cell.</p>

# %%
# first plot
plot_1 = plt.subplot(2,1,1) # 2 Rows, 1 Column, show on 1st panel position in the plot
plt.plot([1600,1700,1800,1900,2000], [1, 1.4, 1.6, 1.8, 2], 'ro-', label = 'First Demographic')
plot_1.set_xlim([1550,2050]) # Lower - Upper bound value
plot_1.set_ylim([0,3])
plt.ylabel('Population (Billions)')
plt.xlabel('Year')
plt.legend()

# second plot
plot_2 = plt.subplot(2, 1, 2) # 2 Rows, 1 Column, show on 2nd panel position in the plot
plt.plot([1600,1700,1800,1900,2000], [2, 2, 3, 3.1, 2.4], 'gx-', label = 'Second Demographic')
plot_2.set_xlim([1550, 2050])
plot_2.set_ylim([1,4])
plt.ylabel('Population (Billions)')
plt.xlabel('Year')
plt.legend()

plt.show()

# %% [markdown]
# ### In-Class Exercise #1 - Create a Graph that Depicts y = f(x)

# %%
import numpy as np

plt.plot([2010, 2012, 2014, 2016, 2018], [30, 38, 24, 45, 30], 'bo-', label='Average Snowfall for Chicago')
plt.ylabel('Inches')
plt.xlabel('Years')
plt.legend()
plt.show()


# HINT: Numpy has a linear space method that can be used here...

# use matplotlib to plot f(x)

# %% [markdown]
# ### Presentation Worthiness
# <p>Before we go into how to use this as a tool for data exploration, let's talk quickly about presentation-worthiness. In the next cell we're going to introduce customization of lines, colors, ticks, titles, fonts, and grids.</p>

# %%
fig, ax = plt.subplots(figsize = (20, 10))
x_axis = np.linspace(-10, 20, 40)
y_axis = 

plt.plot(x,y,
        lw = 5, #Line Width
        ls = '--', # Line Style
        color = 'r', # Line Color
        marker = '-', # Pointer Marker
        markersize = 15, # Marker Size
        markerfacecolor = 'b', # Marker Color
        label = 'Data'
        )
plt.xlabel('X Value', fontname = 'Times New Roman', fontsize=32)
plt.ylabel('Y Value', fontname = 'Times New Roman', fontsize = 32)

plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)

plt.title('Some Visual of F(x) Equation', fontname = 'Times New Roman', fontsize = 40, y = 1.05 )

plt.grid(True)

plt.legend(loc = 'upper left', fontsize = 40)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-944f96c1f67d> in <module>
#       1 fig, ax = plt.subplots(figsize = (20, 10))
#       2
# ----> 3 plt.plot(x,y,
#       4         lw = 5, #Line Width
#       5         ls = '--', # Line Style
#
# NameError: name 'x' is not defined

# %% [markdown]
# <p>It's sometimes nice to obsess a little bit over how your plots look. It's good practice paying attention to detail and it has huge payoff when you end up presenting your findings to other analysts and business parteners. Here's a more complex example of using the matplotlib api:</p>

# %%
markers = ['o', 'v', '^', '*', 's']
styles = ['-', '--', '-.', ':', '-']
colors = ['#588C7E', '#F2E394', '#F2AE72', '#D96459', '#8C4646']

# %%
x = np.linspace(0, 10, 50)

fig,ax = plt.subplots(figsize = (20,10))

# loop in range of 5 to create seprate lines within a chart
for i in range(5):
    plt.plot(x, x ** i,
            lw = 5,
            ls = styles[i],
            color = colors[i],
            marker = markers[i],
            markersize = 15,
            markerfacecolor = colors[i],
            label = f'x^{i}'
            )
    
plt.xlim(0,10,50)
plt.ylim(0,100)

plt.xlabel('X Value', fontname = 'Times New Roman', fontsize = 32)
plt.ylabel('Y Value', fontname = 'Times New Roman', fontsize = 32)

plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)

plt.title('y = f(x) = x^2+', fontname = 'Times New Roman', fontsize = 40, y = 1.05)

plt.grid(True)

plt.legend(loc = 'upper left', fontsize = 40)

plt.tight_layout()
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:127: RuntimeWarning: divide by zero encountered in multiply
#   start = asanyarray(start) * 1.0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:128: RuntimeWarning: divide by zero encountered in multiply
#   stop  = asanyarray(stop)  * 1.0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:134: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = stop - start
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:141: RuntimeWarning: divide by zero encountered in double_scalars
#   step = delta / div
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:151: RuntimeWarning: divide by zero encountered in multiply
#   y *= step
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\function_base.py:161: RuntimeWarning: divide by zero encountered in add
#   y += start
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\figure.py:2241: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\figure.py:2241: RuntimeWarning: divide by zero encountered in less
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\function_base.py:1281: RuntimeWarning: divide by zero encountered in subtract
#   a = op(a[slice1], a[slice2])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2142: RuntimeWarning: divide by zero encountered in less_equal
#   if np.any(np.diff(steps) <= 0) or steps[-1] > 10 or steps[0] < 1:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2155: RuntimeWarning: divide by zero encountered in multiply
#   return np.concatenate([0.1 * steps[:-1], steps, [10 * steps[1]]])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2155: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.concatenate([0.1 * steps[:-1], steps, [10 * steps[1]]])
# <ipython-input-18-55a6637ee3d9>:7: RuntimeWarning: divide by zero encountered in _ones_like
#   plt.plot(x, x ** i,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2031: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 0] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2032: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 1] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2033: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2034: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 0] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2035: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 1] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2036: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2012: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] += tx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2013: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] += ty
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1760: RuntimeWarning: divide by zero encountered in equal
#   return np.all(self.get_matrix() == other.get_matrix())
# <ipython-input-18-55a6637ee3d9>:7: RuntimeWarning: divide by zero encountered in positive
#   plt.plot(x, x ** i,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2031: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 0] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2032: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 1] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2033: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2034: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 0] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2035: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 1] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2036: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2012: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] += tx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2013: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] += ty
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1760: RuntimeWarning: divide by zero encountered in equal
#   return np.all(self.get_matrix() == other.get_matrix())
# <ipython-input-18-55a6637ee3d9>:7: RuntimeWarning: divide by zero encountered in square
#   plt.plot(x, x ** i,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2031: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 0] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2032: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 1] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2033: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2034: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 0] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2035: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 1] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2036: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2012: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] += tx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2013: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] += ty
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1760: RuntimeWarning: divide by zero encountered in equal
#   return np.all(self.get_matrix() == other.get_matrix())
# <ipython-input-18-55a6637ee3d9>:7: RuntimeWarning: divide by zero encountered in power
#   plt.plot(x, x ** i,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2031: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 0] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2032: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 1] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2033: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2034: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 0] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2035: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 1] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2036: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2012: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] += tx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2013: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] += ty
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1760: RuntimeWarning: divide by zero encountered in equal
#   return np.all(self.get_matrix() == other.get_matrix())
# <ipython-input-18-55a6637ee3d9>:7: RuntimeWarning: divide by zero encountered in power
#   plt.plot(x, x ** i,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2012: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] += tx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2013: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] += ty
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1760: RuntimeWarning: divide by zero encountered in equal
#   return np.all(self.get_matrix() == other.get_matrix())
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3438: RuntimeWarning: divide by zero encountered in isfinite
#   and not np.isfinite(converted_limit)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2827: RuntimeWarning: divide by zero encountered in isfinite
#   if (not np.isfinite(vmin)) or (not np.isfinite(vmax)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2840: RuntimeWarning: divide by zero encountered in double_scalars
#   if maxabsvalue < (1e6 / tiny) * np.finfo(float).tiny:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:396: RuntimeWarning: divide by zero encountered in double_scalars
#   return (x0, y0, x1 - x0, y1 - y0)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2265: RuntimeWarning: divide by zero encountered in double_scalars
#   length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2270: RuntimeWarning: divide by zero encountered in double_scalars
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2270: RuntimeWarning: divide by zero encountered in floor
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:96: RuntimeWarning: divide by zero encountered in isnan
#   return um.isnan(a)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:112: RuntimeWarning: divide by zero encountered in clip
#   return ufunc(*args, out=out, **kwargs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2027: RuntimeWarning: divide by zero encountered in true_divide
#   scale = 10 ** (math.log10(dv / n) // 1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2221: RuntimeWarning: divide by zero encountered in true_divide
#   raw_step = (_vmax - _vmin) / nbins
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2222: RuntimeWarning: divide by zero encountered in multiply
#   steps = self._extended_steps * scale
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2228: RuntimeWarning: divide by zero encountered in greater_equal
#   istep = np.nonzero(steps >= raw_step)[0][0]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2240: RuntimeWarning: divide by zero encountered in int_scalars
#   for istep in reversed(range(istep + 1)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2246: RuntimeWarning: divide by zero encountered in double_scalars
#   best_vmin = (_vmin // step) * step
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2253: RuntimeWarning: divide by zero encountered in double_scalars
#   low = edge.le(_vmin - best_vmin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2061: RuntimeWarning: divide by zero encountered in double_scalars
#   d, m = divmod(x, self.step)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2062: RuntimeWarning: divide by zero encountered in double_scalars
#   if self.closeto(m / self.step, 1):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2057: RuntimeWarning: divide by zero encountered in double_scalars
#   return abs(ms - edge) < tol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2254: RuntimeWarning: divide by zero encountered in double_scalars
#   high = edge.ge(_vmax - best_vmin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2068: RuntimeWarning: divide by zero encountered in double_scalars
#   d, m = divmod(x, self.step)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2069: RuntimeWarning: divide by zero encountered in double_scalars
#   if self.closeto(m / self.step, 0):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2255: RuntimeWarning: divide by zero encountered in double_scalars
#   ticks = np.arange(low, high + 1) * step + best_vmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2255: RuntimeWarning: divide by zero encountered in multiply
#   ticks = np.arange(low, high + 1) * step + best_vmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2255: RuntimeWarning: divide by zero encountered in add
#   ticks = np.arange(low, high + 1) * step + best_vmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2257: RuntimeWarning: divide by zero encountered in less_equal
#   nticks = ((ticks <= _vmax) & (ticks >= _vmin)).sum()
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2257: RuntimeWarning: divide by zero encountered in greater_equal
#   nticks = ((ticks <= _vmax) & (ticks >= _vmin)).sum()
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2257: RuntimeWarning: divide by zero encountered in bitwise_and
#   nticks = ((ticks <= _vmax) & (ticks >= _vmin)).sum()
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:2260: RuntimeWarning: divide by zero encountered in add
#   return ticks + offset
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2031: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 0] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2032: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 1] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2033: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[0, 2] *= sx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2034: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 0] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2035: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 1] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2036: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx[1, 2] *= sy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2530: RuntimeWarning: divide by zero encountered in double_scalars
#   length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2534: RuntimeWarning: divide by zero encountered in double_scalars
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2534: RuntimeWarning: divide by zero encountered in floor
#   return int(np.floor(length / size))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\legend.py:791: RuntimeWarning: divide by zero encountered in long_scalars
#   for h, t in handles_and_labels[i0:i0 + di]]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:390: RuntimeWarning: divide by zero encountered in subtract
#   return points[1] - points[0]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:827: RuntimeWarning: divide by zero encountered in double_scalars
#   return Bbox.from_extents(x0, y0, x0 + width, y0 + height)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:202: RuntimeWarning: divide by zero encountered in subtract
#   fig_tops, fig_bottoms = (top - cell_hs).reshape((-1, 2)).T
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:203: RuntimeWarning: divide by zero encountered in add
#   fig_lefts, fig_rights = (left + cell_ws).reshape((-1, 2)).T
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: divide by zero encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:301: RuntimeWarning: divide by zero encountered in int_scalars
#   rowNum1, colNum1 = divmod(num1, cols)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:305: RuntimeWarning: divide by zero encountered in int_scalars
#   rowNum2, colNum2 = divmod(num2, cols)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:307: RuntimeWarning: divide by zero encountered in int_scalars
#   num1num2_list.append((rowNum1 * div_row * max_ncols +
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:308: RuntimeWarning: divide by zero encountered in int_scalars
#   colNum1 * div_col,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:309: RuntimeWarning: divide by zero encountered in int_scalars
#   ((rowNum2 + 1) * div_row - 1) * max_ncols +
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:310: RuntimeWarning: divide by zero encountered in int_scalars
#   (colNum2 + 1) * div_col - 1))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:1041: RuntimeWarning: divide by zero encountered in not_equal
#   if np.any(self._points != other.get_points()):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:813: RuntimeWarning: divide by zero encountered in less_equal
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:813: RuntimeWarning: divide by zero encountered in bitwise_and
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:861: RuntimeWarning: divide by zero encountered in less_equal
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:861: RuntimeWarning: divide by zero encountered in bitwise_and
#   locs = locs[(vmin <= locs) & (locs <= vmax)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:862: RuntimeWarning: divide by zero encountered in absolute
#   locs = np.abs(locs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:891: RuntimeWarning: divide by zero encountered in subtract
#   locs = (np.asarray(_locs) - self.offset) / 10. ** self.orderOfMagnitude
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:891: RuntimeWarning: divide by zero encountered in true_divide
#   locs = (np.asarray(_locs) - self.offset) / 10. ** self.orderOfMagnitude
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:275: RuntimeWarning: divide by zero encountered in reduce
#   umr_maximum(a, axis, None, out, keepdims),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:276: RuntimeWarning: divide by zero encountered in reduce
#   umr_minimum(a, axis, None, None, keepdims),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:274: RuntimeWarning: divide by zero encountered in subtract
#   return um.subtract(
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:58: RuntimeWarning: divide by zero encountered in multiply
#   return bound(*args, **kwds)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:58: RuntimeWarning: divide by zero encountered in rint
#   return bound(*args, **kwds)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   return bound(*args, **kwds)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:908: RuntimeWarning: divide by zero encountered in subtract
#   if np.abs(locs - np.round(locs, decimals=sigfigs)).max() < thresh:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:908: RuntimeWarning: divide by zero encountered in absolute
#   if np.abs(locs - np.round(locs, decimals=sigfigs)).max() < thresh:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\ticker.py:670: RuntimeWarning: divide by zero encountered in double_scalars
#   xp = (x - self.offset) / (10. ** self.orderOfMagnitude)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:1268: RuntimeWarning: divide by zero encountered in double_scalars
#   tol = (hi - lo) * 1e-5
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2904: RuntimeWarning: divide by zero encountered in double_scalars
#   rtol = (b - a) * rtol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2905: RuntimeWarning: divide by zero encountered in double_scalars
#   return a - rtol <= val <= b + rtol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2905: RuntimeWarning: divide by zero encountered in less_equal
#   return a - rtol <= val <= b + rtol
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:379: RuntimeWarning: divide by zero encountered in double_scalars
#   width = xmax - xmin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:380: RuntimeWarning: divide by zero encountered in double_scalars
#   height = ymax - ymin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:392: RuntimeWarning: divide by zero encountered in double_scalars
#   offsetx = (xmin + xmax) / 2
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:432: RuntimeWarning: divide by zero encountered in double_scalars
#   xmin -= offsetx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:433: RuntimeWarning: divide by zero encountered in double_scalars
#   ymin -= offsety
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:438: RuntimeWarning: divide by zero encountered in subtract
#   xys = M.transform(offset_layout) - (offsetx, offsety)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2622: RuntimeWarning: divide by zero encountered in double_scalars
#   x_scale = 1.0 / inw
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2623: RuntimeWarning: divide by zero encountered in double_scalars
#   y_scale = 1.0 / inh
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2624: RuntimeWarning: divide by zero encountered in double_scalars
#   self._mtx = np.array([[x_scale, 0.0    , (-inl*x_scale)],
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:2625: RuntimeWarning: divide by zero encountered in double_scalars
#   [0.0    , y_scale, (-inb*y_scale)],
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:652: RuntimeWarning: divide by zero encountered in add
#   return Bbox(self._points + (tx, ty))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2095: RuntimeWarning: divide by zero encountered in double_scalars
#   (x, bottom - self.labelpad * self.figure.dpi / 72)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2127: RuntimeWarning: divide by zero encountered in double_scalars
#   y = bottom - self.OFFSETTEXTPAD * self.figure.dpi / 72
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:378: RuntimeWarning: divide by zero encountered in double_scalars
#   return points[1, 0] - points[0, 0]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:1107: RuntimeWarning: divide by zero encountered in double_scalars
#   bb.x0 = (bb.x0 + bb.x1) / 2 - 0.5
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:1108: RuntimeWarning: divide by zero encountered in double_scalars
#   bb.x1 = bb.x0 + 1.0
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:384: RuntimeWarning: divide by zero encountered in double_scalars
#   return points[1, 1] - points[0, 1]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:405: RuntimeWarning: divide by zero encountered in double_scalars
#   offsety = ymin + height - baseline / 2.0
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2366: RuntimeWarning: divide by zero encountered in double_scalars
#   (left - self.labelpad * self.figure.dpi / 72, y)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:2392: RuntimeWarning: divide by zero encountered in double_scalars
#   (x, top + self.OFFSETTEXTPAD * self.figure.dpi / 72)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:413: RuntimeWarning: divide by zero encountered in double_scalars
#   offsetx = (xmin1 + xmax1) / 2.0
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:1110: RuntimeWarning: divide by zero encountered in double_scalars
#   bb.y0 = (bb.y0 + bb.y1) / 2 - 0.5
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axis.py:1111: RuntimeWarning: divide by zero encountered in double_scalars
#   bb.y1 = bb.y0 + 1.0
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:403: RuntimeWarning: divide by zero encountered in double_scalars
#   offsety = ymin + descent
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:4464: RuntimeWarning: divide by zero encountered in double_scalars
#   bt.x0 = (bt.x0 + bt.x1) / 2 - 0.5
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:4465: RuntimeWarning: divide by zero encountered in double_scalars
#   bt.x1 = bt.x0 + 1.0
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:692: RuntimeWarning: divide by zero encountered in maximum
#   x0 = np.maximum(bbox1.xmin, bbox2.xmin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:693: RuntimeWarning: divide by zero encountered in minimum
#   x1 = np.minimum(bbox1.xmax, bbox2.xmax)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:694: RuntimeWarning: divide by zero encountered in maximum
#   y0 = np.maximum(bbox1.ymin, bbox2.ymin)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:695: RuntimeWarning: divide by zero encountered in minimum
#   y1 = np.minimum(bbox1.ymax, bbox2.ymax)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:4480: RuntimeWarning: divide by zero encountered in equal
#   if np.all(clip_extent.extents == axbbox.extents):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:180: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.x0 = bb0.x0 - padout
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.x1 = bb0.x1 + padin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:183: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.y0 = bb0.y0 - padout
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\spines.py:184: RuntimeWarning: divide by zero encountered in double_scalars
#   bb0.y1 = bb0.y1 + padin
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:833: RuntimeWarning: divide by zero encountered in double_scalars
#   h_d = max(h_ - d_, h - yd)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:101: RuntimeWarning: divide by zero encountered in double_scalars
#   offsets_ = np.cumsum([0] + [w + sep for w in w_list])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:104: RuntimeWarning: divide by zero encountered in double_scalars
#   total = offsets_[-1] - sep
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:497: RuntimeWarning: divide by zero encountered in add
#   xoffsets = xoffsets_ + [xd for w, h, xd, yd in whd_list]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:500: RuntimeWarning: divide by zero encountered in subtract
#   xoffsets = xoffsets - xdescent
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:502: RuntimeWarning: divide by zero encountered in double_scalars
#   return (width + 2 * pad, height + 2 * pad,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:168: RuntimeWarning: divide by zero encountered in double_scalars
#   height_descent = max(h - d for h, d in hd_list)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:170: RuntimeWarning: divide by zero encountered in double_scalars
#   height = height_descent + descent
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:451: RuntimeWarning: divide by zero encountered in add
#   yoffsets = yoffsets_ + [yd for w, h, xd, yd in whd_list]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:452: RuntimeWarning: divide by zero encountered in double_scalars
#   ydescent = height - yoffsets[0]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:453: RuntimeWarning: divide by zero encountered in subtract
#   yoffsets = height - yoffsets
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:455: RuntimeWarning: divide by zero encountered in subtract
#   yoffsets = yoffsets - ydescent
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:457: RuntimeWarning: divide by zero encountered in double_scalars
#   return (width + 2 * pad, height + 2 * pad,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:458: RuntimeWarning: divide by zero encountered in double_scalars
#   xdescent + pad, ydescent + pad,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:481: RuntimeWarning: divide by zero encountered in double_scalars
#   height_descent = max(h - yd for w, h, xd, yd in whd_list)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:483: RuntimeWarning: divide by zero encountered in double_scalars
#   height = height_descent + ydescent
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:503: RuntimeWarning: divide by zero encountered in double_scalars
#   xdescent + pad, ydescent + pad,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:440: RuntimeWarning: divide by zero encountered in double_scalars
#   whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:180: RuntimeWarning: divide by zero encountered in double_scalars
#   offsets = [(height - h) * .5 + d for h, d in hd_list]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:648: RuntimeWarning: divide by zero encountered in add
#   return Bbox(points + [[-p, -p], [p, p]])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:546: RuntimeWarning: divide by zero encountered in double_scalars
#   [(l + cx * (w - W)) - L,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:547: RuntimeWarning: divide by zero encountered in double_scalars
#   (b + cy * (h - H)) - B])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\transforms.py:545: RuntimeWarning: divide by zero encountered in add
#   return Bbox(self._points +
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\legend.py:586: RuntimeWarning: divide by zero encountered in double_scalars
#   return x + xdescent, y + ydescent
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:354: RuntimeWarning: divide by zero encountered in double_scalars
#   return mtransforms.Bbox.from_bounds(px - xd, py - yd, w, h)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:327: RuntimeWarning: divide by zero encountered in not_equal
#   mask[1:] = aux[1:] != aux[:-1]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:432: RuntimeWarning: divide by zero encountered in equal
#   mask = aux[1:] == aux[:-1]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: RuntimeWarning: divide by zero encountered in equal
#   mask |= (ar1 == a)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask |= (ar1 == a)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:92: RuntimeWarning: divide by zero encountered in int_scalars
#   row1, col1 = divmod(num1, cols)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:95: RuntimeWarning: divide by zero encountered in int_scalars
#   row2, col2 = divmod(num2, cols)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:97: RuntimeWarning: divide by zero encountered in int_scalars
#   for row_i in range(row1, row2 + 1):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:98: RuntimeWarning: divide by zero encountered in double_scalars
#   hspaces[row_i, col1] += ax_bbox.xmin - tight_bbox.xmin  # left
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:99: RuntimeWarning: divide by zero encountered in int_scalars
#   hspaces[row_i, col2 + 1] += tight_bbox.xmax - ax_bbox.xmax  # right
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:99: RuntimeWarning: divide by zero encountered in double_scalars
#   hspaces[row_i, col2 + 1] += tight_bbox.xmax - ax_bbox.xmax  # right
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:100: RuntimeWarning: divide by zero encountered in int_scalars
#   for col_i in range(col1, col2 + 1):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:101: RuntimeWarning: divide by zero encountered in double_scalars
#   vspaces[row1, col_i] += tight_bbox.ymax - ax_bbox.ymax  # top
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:102: RuntimeWarning: divide by zero encountered in int_scalars
#   vspaces[row2 + 1, col_i] += ax_bbox.ymin - tight_bbox.ymin  # bot.
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:102: RuntimeWarning: divide by zero encountered in double_scalars
#   vspaces[row2 + 1, col_i] += ax_bbox.ymin - tight_bbox.ymin  # bot.
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:110: RuntimeWarning: divide by zero encountered in double_scalars
#   + pad_inches / fig_width_inch)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:109: RuntimeWarning: divide by zero encountered in double_scalars
#   margin_left = (max(hspaces[:, 0].max(), 0)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:119: RuntimeWarning: divide by zero encountered in double_scalars
#   + pad_inches / fig_width_inch)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:118: RuntimeWarning: divide by zero encountered in double_scalars
#   margin_right = (max(hspaces[:, -1].max(), 0)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:122: RuntimeWarning: divide by zero encountered in double_scalars
#   + pad_inches / fig_height_inch)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:121: RuntimeWarning: divide by zero encountered in double_scalars
#   margin_top = (max(vspaces[0, :].max(), 0)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:129: RuntimeWarning: divide by zero encountered in double_scalars
#   + pad_inches / fig_height_inch)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:128: RuntimeWarning: divide by zero encountered in double_scalars
#   margin_bottom = (max(vspaces[-1, :].max(), 0)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:136: RuntimeWarning: divide by zero encountered in double_scalars
#   if margin_left + margin_right >= 1:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:141: RuntimeWarning: divide by zero encountered in double_scalars
#   if margin_bottom + margin_top >= 1:
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:148: RuntimeWarning: divide by zero encountered in double_scalars
#   right=1 - margin_right,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_layout.py:150: RuntimeWarning: divide by zero encountered in double_scalars
#   top=1 - margin_top)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:183: RuntimeWarning: divide by zero encountered in double_scalars
#   tot_width = right - left
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:184: RuntimeWarning: divide by zero encountered in double_scalars
#   tot_height = top - bottom
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:187: RuntimeWarning: divide by zero encountered in double_scalars
#   cell_h = tot_height / (nrows + hspace*(nrows-1))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:188: RuntimeWarning: divide by zero encountered in double_scalars
#   sep_h = hspace * cell_h
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:189: RuntimeWarning: divide by zero encountered in double_scalars
#   norm = cell_h * nrows / sum(self._row_height_ratios)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:190: RuntimeWarning: divide by zero encountered in double_scalars
#   cell_heights = [r * norm for r in self._row_height_ratios]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   cell_w = tot_width / (ncols + wspace*(ncols-1))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:196: RuntimeWarning: divide by zero encountered in double_scalars
#   sep_w = wspace * cell_w
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:197: RuntimeWarning: divide by zero encountered in double_scalars
#   norm = cell_w * ncols / sum(self._col_width_ratios)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\gridspec.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   cell_widths = [r * norm for r in self._col_width_ratios]
# C:\Users\todds\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py:195: RuntimeWarning: divide by zero encountered in greater
#   return rgbaArr[:,:3].dot((.299, .587, .114)) > .5
# C:\Users\todds\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py:184: RuntimeWarning: divide by zero encountered in equal
#   if ticksLight.size and (ticksLight == ticksLight[0]).all():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:687: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(posx) or not np.isfinite(posy):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:709: RuntimeWarning: divide by zero encountered in double_scalars
#   x = x + posx
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:710: RuntimeWarning: divide by zero encountered in double_scalars
#   y = y + posy
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\text.py:712: RuntimeWarning: divide by zero encountered in double_scalars
#   y = canvash - y
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backend_bases.py:948: RuntimeWarning: divide by zero encountered in less
#   if np.any(dl < 0.0):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:3789: RuntimeWarning: divide by zero encountered in double_scalars
#   y, height = y / m_aspect, height / m_aspect
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2211: RuntimeWarning: divide by zero encountered in double_scalars
#   width, height = width + 2 * pad, height + 2 * pad
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2213: RuntimeWarning: divide by zero encountered in double_scalars
#   x0, y0 = x0 - pad, y0 - pad,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2214: RuntimeWarning: divide by zero encountered in double_scalars
#   x1, y1 = x0 + width, y0 + height
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2218: RuntimeWarning: divide by zero encountered in double_scalars
#   cp = [(x0 + dr, y0),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2219: RuntimeWarning: divide by zero encountered in double_scalars
#   (x1 - dr, y0),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2220: RuntimeWarning: divide by zero encountered in double_scalars
#   (x1, y0), (x1, y0 + dr),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2221: RuntimeWarning: divide by zero encountered in double_scalars
#   (x1, y1 - dr),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2222: RuntimeWarning: divide by zero encountered in double_scalars
#   (x1, y1), (x1 - dr, y1),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2223: RuntimeWarning: divide by zero encountered in double_scalars
#   (x0 + dr, y1),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2224: RuntimeWarning: divide by zero encountered in double_scalars
#   (x0, y1), (x0, y1 - dr),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2225: RuntimeWarning: divide by zero encountered in double_scalars
#   (x0, y0 + dr),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2226: RuntimeWarning: divide by zero encountered in double_scalars
#   (x0, y0), (x0 + dr, y0),
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:2227: RuntimeWarning: divide by zero encountered in double_scalars
#   (x0 + dr, y0)]
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:3804: RuntimeWarning: divide by zero encountered in multiply
#   vertices[:, 1] = vertices[:, 1] * m_aspect
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\offsetbox.py:367: RuntimeWarning: divide by zero encountered in double_scalars
#   c.set_offset((px + ox, py + oy))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\figure.py:1651: RuntimeWarning: divide by zero encountered in isfinite
#   if (np.isfinite(b.width) and np.isfinite(b.height)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_bbox.py:65: RuntimeWarning: divide by zero encountered in double_scalars
#   w1, h1 = fig.bbox.width * dpi_scale, fig.bbox.height * dpi_scale
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_bbox.py:71: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.patch.set_bounds(x0 / w1, y0 / h1,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\tight_bbox.py:72: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.bbox.width / w1, fig.bbox.height / h1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:768: RuntimeWarning: divide by zero encountered in double_scalars
#   x1 = self.convert_xunits(self._x0 + self._width)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\patches.py:769: RuntimeWarning: divide by zero encountered in double_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:213: RuntimeWarning: divide by zero encountered in double_scalars
#   x = round(x + xo + xd)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:213: RuntimeWarning: divide by zero encountered in rint
#   x = round(x + xo + xd)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: divide by zero encountered in double_scalars
#   y = round(y + yo + yd)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: divide by zero encountered in rint
#   y = round(y + yo + yd)

# %% [markdown]
# ### In-Class Exercise #2 - Customize the f(x) Plot Created Earlier <br>
# <p>Customize it however you would like...</p>

# %%
plt.plot([2010, 2012, 2014, 2016, 2018], [30, 38, 24, 45, 30], 'bo-', label='Average Snowfall for Chicago')
plt.ylabel('Inches')
plt.xlabel('Years')
plt.title("Chicago's Worst Season - Winter", fontname = 'cursive', fontsize = 25, y = 1.05 )
plt.legend()
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
import csv
from itertools import groupby

def read_csv(filename):
    with open(filename, 'r') as f:
        data = list(csv.reader(f))
    return data

flowers = read_csv('files/iris.csv')

# %%
import csv
from  itertools import groupby

data_file = 'files/iris.csv'

plt.figure(figsize = (10.5, 7.25))

def read_csv(filename):
    with open(filename, 'r') as f:
        data = list(csv.reader(f))
    return data

flowers = read_csv(data_file)

# print(flowers)

colors = {
    'Iris-setosa': '#2B5B84', # Dark Blue/Purplish
    'Iris-versicolor': 'g',
    'Iris-virginica': 'purple'
}

flowers.pop()

for species, group in groupby(flowers, lambda x: x[4]):
    flower_cat = list(group)
    sepal_length = [float(flower[0]) for flower in flower_cat]
    sepal_width = [float(flower[1]) for flower in flower_cat]
    plt.scatter(sepal_length, sepal_width, s = 10, c = colors[species], label = species)

plt.title('Iris DataSet Sepal Length X Width', fontsize = 16)
plt.xlabel('Sepal Length (cm)', fontsize = 10)
plt.ylabel('Sepal Width (cm)', fontsize = 10)
plt.legend(loc = 'best').get_frame().set_color('chocolate')
plt.show()
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\ma\core.py:2360: RuntimeWarning: divide by zero encountered in isfinite
#   condition = ~(np.isfinite(getdata(a)))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\ma\core.py:2360: RuntimeWarning: divide by zero encountered in invert
#   condition = ~(np.isfinite(getdata(a)))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\colors.py:349: RuntimeWarning: divide by zero encountered in less
#   if np.any((result < 0) | (result > 1)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\colors.py:349: RuntimeWarning: divide by zero encountered in greater
#   if np.any((result < 0) | (result > 1)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\colors.py:349: RuntimeWarning: divide by zero encountered in bitwise_or
#   if np.any((result < 0) | (result > 1)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\lines.py:69: RuntimeWarning: divide by zero encountered in double_scalars
#   scaled_offset = offset * lw
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\collections.py:1003: RuntimeWarning: divide by zero encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\collections.py:1003: RuntimeWarning: divide by zero encountered in multiply
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\collections.py:1003: RuntimeWarning: divide by zero encountered in true_divide
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# C:\Users\todds\anaconda3\lib\site-packages\numpy\ma\core.py:2365: RuntimeWarning: divide by zero encountered in isfinite
#   condition = ~(np.isfinite(a))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\ma\core.py:2365: RuntimeWarning: divide by zero encountered in invert
#   condition = ~(np.isfinite(a))
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2065: RuntimeWarning: divide by zero encountered in isinf
#   if not np.isinf(datalim.minpos).all():
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2284: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.any(np.isfinite(xys)):
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\legend_handler.py:201: RuntimeWarning: divide by zero encountered in multiply
#   ydata = height * legend._scatteryoffsets
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\legend_handler.py:402: RuntimeWarning: divide by zero encountered in multiply
#   size_max = max(handle_sizes) * legend.markerscale ** 2
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\legend_handler.py:403: RuntimeWarning: divide by zero encountered in multiply
#   size_min = min(handle_sizes) * legend.markerscale ** 2
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\legend_handler.py:407: RuntimeWarning: divide by zero encountered in double_scalars
#   sizes = [.5 * (size_max + size_min), size_max,
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:199: RuntimeWarning: divide by zero encountered in multiply
#   self._px = (self._cpoints.T * coeff).T
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:216: RuntimeWarning: divide by zero encountered in subtract
#   return (np.power.outer(1 - t, self._orders[::-1])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:216: RuntimeWarning: divide by zero encountered in power
#   return (np.power.outer(1 - t, self._orders[::-1])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:217: RuntimeWarning: divide by zero encountered in power
#   * np.power.outer(t, self._orders)) @ self._px
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:216: RuntimeWarning: divide by zero encountered in multiply
#   return (np.power.outer(1 - t, self._orders[::-1])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:216: RuntimeWarning: divide by zero encountered in matmul
#   return (np.power.outer(1 - t, self._orders[::-1])
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:273: RuntimeWarning: divide by zero encountered in add
#   prefactor = (-1)**(i + j) * _comb(j, i)  # j on axis 0, i on axis 1
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:273: RuntimeWarning: divide by zero encountered in power
#   prefactor = (-1)**(i + j) * _comb(j, i)  # j on axis 0, i on axis 1
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:20: RuntimeWarning: divide by zero encountered in long_scalars
#   k = min(k, n - k)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:21: RuntimeWarning: divide by zero encountered in long_scalars
#   i = np.arange(1, k + 1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:22: RuntimeWarning: divide by zero encountered in long_scalars
#   return np.prod((n + 1 - i)/i).astype(int)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:22: RuntimeWarning: divide by zero encountered in subtract
#   return np.prod((n + 1 - i)/i).astype(int)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:22: RuntimeWarning: divide by zero encountered in true_divide
#   return np.prod((n + 1 - i)/i).astype(int)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\function_base.py:2197: RuntimeWarning: divide by zero encountered in _comb (vectorized)
#   outputs = ufunc(*inputs)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:273: RuntimeWarning: divide by zero encountered in multiply
#   prefactor = (-1)**(i + j) * _comb(j, i)  # j on axis 0, i on axis 1
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:274: RuntimeWarning: divide by zero encountered in multiply
#   return _comb(n, j) * prefactor @ P  # j on axis 0, self.dimension on 1
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:274: RuntimeWarning: divide by zero encountered in matmul
#   return _comb(n, j) * prefactor @ P  # j on axis 0, self.dimension on 1
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:296: RuntimeWarning: divide by zero encountered in multiply
#   dCj = np.arange(1, n+1)[:, None] * Cj[1:]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\polynomial.py:241: RuntimeWarning: divide by zero encountered in int_scalars
#   trailing_zeros = len(p) - non_zero[-1] - 1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\polynomial.py:254: RuntimeWarning: divide by zero encountered in negative
#   A[0,:] = -p[1:] / p[0]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\polynomial.py:254: RuntimeWarning: divide by zero encountered in true_divide
#   A[0,:] = -p[1:] / p[0]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\linalg\linalg.py:207: RuntimeWarning: divide by zero encountered in isfinite
#   if not isfinite(a).all():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\linalg\linalg.py:1071: RuntimeWarning: divide by zero encountered in equal
#   if all(w.imag == 0):
# C:\Users\todds\anaconda3\lib\site-packages\numpy\lib\type_check.py:276: RuntimeWarning: divide by zero encountered in equal
#   return imag(x) == 0
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:305: RuntimeWarning: divide by zero encountered in greater_equal
#   in_range = np.isreal(roots) & (roots >= 0) & (roots <= 1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:305: RuntimeWarning: divide by zero encountered in bitwise_and
#   in_range = np.isreal(roots) & (roots >= 0) & (roots <= 1)
# C:\Users\todds\anaconda3\lib\site-packages\matplotlib\bezier.py:305: RuntimeWarning: divide by zero encountered in less_equal
#   in_range = np.isreal(roots) & (roots >= 0) & (roots <= 1)

# %% [markdown]
# ### Box Plot

# %%
from itertools import groupby

plt.figure(figsize = (10.5,7.25))

fig = plt.figure()

flowers = read_csv(data_file)

petal_length = []

for species, group in groupby(flowers, lambda x: x[4]):
    petal_length.append([float(petal[2]) for petal in group])

plt.boxplot(petal_length)
plt.axis([0, 4 , 0, 10]) # xmin , xmax , ymin, ymax
plt.xticks([1,2,3], ['Setosa','Versicolor', 'Virginica'])
plt.title('Box Plot with Iris Dataset', fontsize = 16, loc = 'right')
plt.xlabel('Flower Variety', fontsize = 10)
plt.ylabel('Petal Length (cm)', fontsize = 10)

plt.show()

# Save the figure as a png to local files folder
fig.savefig('../files/iris_petal_length_data.png')

# %% [markdown]
# ### Histograms <br>
# <p>While line plots are great for visualizing trends in time series data, histograms are the king of visualizing distributions. Often, the distribution of a variable is what you're interested in, and a visualization provides a lot more information than a group of summary statistics.</p>

# %%
fig, ax = plt.subplots(figsize=(16, 9)) #Subplots makes a call in the background to create a plot area

# generate random data
data = np.random.uniform(0,10,1000000000)

# Plot Histogram
plt.hist(data,bins = 75, label = 'Data', color = 'r', alpha = 0.75)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)

plt.xlabel('Value', fontsize = 35, fontname = 'Times New Roman')
plt.ylabel('Frequency', fontname = 'Times New Roman', fontsize = 35)
plt.legend(loc = 'upper left', fontsize = 30)

plt.show()
# Out:
# <ipython-input-39-ea9ab04b1d08>:4: RuntimeWarning: divide by zero encountered in isfinite
#   data = np.random.uniform(0,10,1000000000)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-ea9ab04b1d08> in <module>
#       2
#       3 # generate random data
# ----> 4 data = np.random.uniform(0,10,1000000000)
#       5
#       6 # Plot Histogram
#
# mtrand.pyx in numpy.random.mtrand.RandomState.uniform()
#
# _common.pyx in numpy.random._common.cont()
#
# ValueError: array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.

# %% [markdown]
# <p>Let's take a look at a mystery/randomly generated DataFrame, and plot the results</p>

# %%
import pandas as pd
import numpy as np

def make_mystery_dataframe():
    customer_id = np.random.randint(1000,1200,10000)
    states = {1: 'California', 0: 'Colorado'}
    statelist = []
    agelist = []
    for i in range(10000):
        ind = np.random.randint(0,2)
        if ind == 0:
            statelist.append(states[ind])
            agelist.append(abs(np.random.normal(loc = 30, scale = 10)))
        elif ind == 1:
            statelist.append(states[ind])
            agelist.append(abs(np.random.normal(loc = 40, scale = 20)))
    mystery_df = pd.DataFrame.from_dict({
        'customer_id': customer_id,
        'ages':agelist,
        'state': statelist
    })
    return mystery_df
df = make_mystery_dataframe()
df.head(20)
# Out:
#     customer_id       ages       state
# 0          1145  26.732482    Colorado
# 1          1186  48.222290    Colorado
# 2          1058  58.990500  California
# 3          1197  27.962741    Colorado
# 4          1018  52.621505    Colorado
# 5          1155  32.171043    Colorado
# 6          1142  38.451615    Colorado
# 7          1078  69.680742  California
# 8          1152  39.149070    Colorado
# 9          1139  34.761612  California
# 10         1126  47.505187  California
# 11         1140  30.300764    Colorado
# 12         1158  21.518021    Colorado
# 13         1003  50.226082  California
# 14         1145  41.359204    Colorado
# 15         1077  47.870014  California
# 16         1036  25.459055    Colorado
# 17         1110  16.406345  California
# 18         1184  32.151709    Colorado
# 19         1150  30.362639    Colorado

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

# first subplot - histogram
ax1.hist(df[df['state'] == 'California']['ages'], bins = 80, label = 'Ages in Cali')
ax1.set_xlabel('Value', fontname = 'Times New Roman', fontsize = 35)
ax1.set_ylabel('Frequency', fontname='Times New Roman', fontsize = 35)
ax1.tick_params(axis = 'both', labelsize = 30)
ax1.legend(loc = 'upper left', fontsize = 30)

# second subplot - histogram
ax2.hist(df[df['state'] == 'Colorado']['ages'], bins = 80, label = 'Ages in Colorado')
ax2.set_xlabel('Value', fontname = 'Times New Roman', fontsize = 35)
ax2.set_ylabel('Frequency', fontname = 'Times New Roman', fontsize = 35)
ax2.tick_params(axis = 'both', labelsize = 30)
ax2.legend(loc = 'upper left', fontsize = 30)
